# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Comparison

# %% [markdown]
# ### Bar chart

# %% [markdown]
# # Time Series

# %%
dataframe=pd.read_csv('https://raw.githubusercontent.com/AnirbanMukherjeeXD/samsung-stock-price-prediction/master/Samsung_Stock_Data.csv').dropna()

#Formatting Date
dataframe['Date']=pd.to_datetime(dataframe['Date'],format='%Y-%m-%d')

# %%
plt.figure(figsize=(10,5))
sns.lineplot(dataframe['Date'],dataframe['High'])
#plt.xlim(pd.Timestamp('2018-10-30'), pd.Timestamp('2019-04-30'))

# %% [markdown]
# # Distribution

# %%
sns.distplot(dataframe['High'])

# %%
sns.distplot(dataframe['Volume'])

# %% [markdown]
# # Relationship

# %% [markdown]
# ### Scatter
